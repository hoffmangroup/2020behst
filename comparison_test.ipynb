# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Estimated expression levels from RSEM as a tsv file. The columns are as follows:
#
# column 1: gene_id - gene name of the gene the transcript belongs to (parent gene). If no gene information is provided, gene_id and transcript_id is the same.
# column 2: transcript_id(s) - transcript name of this transcript
# column 3: length - the transcript's sequence length (poly(A) tail is not counted)
# column 4: effective_length - the length containing only the positions that can generate a valid fragment
# column 5: expected_count - the sum of the posterior probability of each read comes from this transcript over all reads
# column 6: TPM - transcripts per million, a measure of relative measure of transcript abundance
# column 7: FPKM - fragments per kilobase of transcript per million mapped reads, another relative measure of transcript abundance
# column 8: posterior_mean_count - posterior mean estimate calcualted by RSEM's Gibbs sampler
# column 9: posterior_standard_deviation_of_count - posterior standard deviation of counts
# column 10: pme_TPM - posterior mean estimate of TPM
# column 11: pme_FPKM - posterior mean estimate of FPKM
# column 12: TPM_ci_lower_bound - lower bound of 95% credibility interval for TPM values
# column 13: TPM_ci_upper_bound - upper bound of 95% credibility interval for TPM values
# column 14: FPKM_ci_lower_bound - lower bound of 95% credibility interval for FPKM values
# column 15: FPKM_ci_upper_bound - upper bound of 95% credibility interval for FPKM values

# %%
# load Mouse ENCODE E11.5 data
limb_1 = pd.read_csv("../BEHST/data/ENCFF195JHC.tsv", sep='\t', header=0)
limb_2 = pd.read_csv("../BEHST/data/ENCFF457ZGF.tsv", sep='\t',header=0)
forebrain_1 = pd.read_csv("../BEHST/data/ENCFF465SNB.tsv", sep='\t', header=0)
forebrain_2 = pd.read_csv("../BEHST/data/ENCFF976OLT.tsv", sep='\t', header=0)
midbrain_1 = pd.read_csv("../BEHST/data/ENCFF359ZOA.tsv", sep='\t', header=0)
midbrain_2 = pd.read_csv("../BEHST/data/ENCFF971KZC.tsv", sep='\t', header=0)
hindbrain_1 = pd.read_csv("../BEHST/data/ENCFF750FTK.tsv", sep='\t', header=0)
hindbrain_2 = pd.read_csv("../BEHST/data/ENCFF109HTF.tsv", sep='\t', header=0)
heart_1 = pd.read_csv("../BEHST/data/ENCFF226IWR.tsv", sep='\t', header=0)
heart_2 = pd.read_csv("../BEHST/data/ENCFF540EJL.tsv", sep='\t', header=0)
liver_1 = pd.read_csv("../BEHST/data/ENCFF954EHG.tsv", sep='\t', header=0)
liver_2 = pd.read_csv("../BEHST/data/ENCFF523MEO.tsv", sep='\t', header=0)
neural_tube_1 = pd.read_csv("../BEHST/data/ENCFF375JDR.tsv", sep='\t', header=0)
neural_tube_2 = pd.read_csv("../BEHST/data/ENCFF298WHK.tsv", sep='\t', header=0)
facial_1 = pd.read_csv("../BEHST/data/ENCFF772UWT.tsv", sep='\t', header=0)
facial_2 = pd.read_csv("../BEHST/data/ENCFF262TXH.tsv", sep='\t', header=0)

# %%
# Ensemble orthologous genes
gene_ids = pd.read_csv("../BEHST/data/human_mouse_gene_id.txt", sep='\t')
gene_ids = gene_ids.rename(columns={'Mouse gene stable ID': 'gene_id'})

# %%
gene_ids.head()
# Out:
#     Gene stable ID             gene_id Mouse gene name Mouse homology type
# 0  ENSG00000198888  ENSMUSG00000064341          mt-Nd1    ortholog_one2one
# 1  ENSG00000198763  ENSMUSG00000064345          mt-Nd2    ortholog_one2one
# 2  ENSG00000198804  ENSMUSG00000064351          mt-Co1    ortholog_one2one
# 3  ENSG00000198712  ENSMUSG00000064354          mt-Co2    ortholog_one2one
# 4  ENSG00000228253  ENSMUSG00000064356         mt-Atp8    ortholog_one2one

# %% [markdown]
# #### Defining Tissue-specific Genes
# Tissue-specific genes are defined using the algorithm from the HPA (Uhlén et al. 2015), and can be grouped as follows:
#
# - Tissue Enriched: Genes with an expression level greater than 1 (TPM or FPKM) that also have at least five-fold higher expression levels in a particular tissue compared to all other tissues.
# - Group Enriched: Genes with an expression level greater than 1 (TPM or FPKM) that also have at least five-fold higher expression levels in a group of 2-7 tissues compared to all other tissues, and that are not considered Tissue Enriched.
# - Tissue Enhanced: Genes with an expression level greater than 1 (TPM or FPKM) that also have at least five-fold higher expression levels in a particular tissue compared to the average levels in all other tissues, and that are not considered Tissue Enriched or Group Enriched.

# %%
def calculate_mean(df_list):
    """
    Calculate the mean values of the isogenic replicates of gene quantifications.
    """
    df_all = pd.concat(df_list)
    df_mean = df_all.groupby(['gene_id']).mean()
    df_mean = df_mean.reset_index()
    
    # TODO: can drop unused columns here
    return df_mean

# %%
def select_genes(tissue_dfs, other_dfs):
    """
    select most highly expressed genes in this tissue
    """
    tissue_mean = calculate_mean(tissue_dfs)
    other_mean = calculate_mean(other_dfs)
    
    # select highly expressed genes in this tissue
    tissue_genes = tissue_mean[tissue_mean['pme_TPM'] > 1]
    
    # compare with other types
    tissue_enhanced = pd.merge(tissue_genes, other_mean, on='gene_id')
    tissue_enhanced = tissue_enhanced.rename(columns={'pme_TPM_x': 'tissue_TPM', 'pme_TPM_y': 'other_TPM'})
    # select useful columns
    tissue_enhanced = tissue_enhanced[['gene_id', 'tissue_TPM', 'other_TPM']]
    
    df_enhanced = tissue_enhanced[tissue_enhanced['tissue_TPM'] >= (5 * tissue_enhanced['other_TPM'])].copy()
    
    # convert to mouse stable id
    df_enhanced['gene_id'] = df_enhanced['gene_id'].str.split('.').str.get(0)
    
    return df_enhanced

# %%
def merge_df(go_df, ref_df, keys, sig):
    """
    go_df is the output GO term dataframe, ref_df is the ground-truth term dataframe,
    keys are list of columns to be merged on.
    Return a tuple of dataframes, where the first dataframe is true positive terms,
    the second dataframe is false negative terms.
    """
    # select significant terms
    if sig == True and 'p_value' in go_df.columns:
        go_df = go_df[go_df['p_value'] <= 0.05]
    
    res = go_df.merge(ref_df, on=keys, how='left', indicator=True)
    res_pos = res[res['_merge'] == 'both']
    res_neg = res[res['_merge'] == 'left_only']
    
    print("The number of true positive terms is", len(res_pos))
    print("The number of false positive terms is", len(res_neg))
    
    return res_pos, res_neg

# %%
def top_50(go_df, ref_df):
    # select top 50 terms by p-value
    top_50 = go_df.sort_values('p_value').head(50)
    
    # select columns to merge on
    if {'source', 'term_name'}.issubset(top_50.columns):
        top_res = merge_df(top_50, ref_df, ['term_id', 'source', 'term_name'], False)
    else:
        top_res = merge_df(top_50, ref_df, ['term_id'], False)
    
    return top_res

# %% [markdown]
# ## BEHST Limb

# %%
# select most highly expressed genes in limb
limb_df = select_genes([limb_1, limb_2], 
                       [forebrain_1, forebrain_2, midbrain_1, midbrain_2, hindbrain_1, hindbrain_2, 
                       heart_1, heart_2, liver_1, liver_2, neural_tube_1, neural_tube_2, facial_1, facial_2])

len(limb_df)
# Out:
# 97

# %%
# select genes with mappable id for homo sapiens
mapped = pd.merge(limb_df, gene_ids, on='gene_id', how='inner')
len(mapped)

# mapped[['Gene stable ID']].to_csv('../BEHST/data/06_24_reference_limb_gene_id', header=None, index=None)
# Out:
# 69

# %%
mapped[mapped['Mouse homology type'] == 'ortholog_one2many']
# Out:
#                gene_id  tissue_TPM  other_TPM   Gene stable ID  \
# 67  ENSMUSG00000084897       8.655   1.140714  ENSG00000242950
#
#    Mouse gene name Mouse homology type
# 67         Gm14226   ortholog_one2many

# %%
gene_ids[gene_ids['gene_id'] == 'ENSMUSG00000097052'].head(50)
# Out:
#       Gene stable ID             gene_id Mouse gene name Mouse homology type
# 31   ENSG00000280496  ENSMUSG00000097052         Snora43  ortholog_many2many
# 722  ENSG00000252461  ENSMUSG00000097052         Snora43  ortholog_many2many

# %%
# run gprofiler2 on the mapped genes, get this GO list as reference
limb_ref = pd.read_csv("../BEHST/results/06-24/limb_go_list", sep="\t", header=0)
len(limb_ref)
# Out:
# 2336

# %%
# select significant terms
limb_ref = limb_ref[limb_ref.p_value <= 0.05]
limb_ref
# Out:
#           p_value     term_id source  \
# 0    1.520378e-26  GO:0060173  GO:BP
# 1    1.520378e-26  GO:0048736  GO:BP
# 2    5.502065e-23  GO:0035107  GO:BP
# 3    5.502065e-23  GO:0035108  GO:BP
# 4    1.153630e-22  GO:0035113  GO:BP
# ..            ...         ...    ...
# 173  3.137960e-02  GO:0044271  GO:BP
# 174  3.174007e-02  GO:0045445  GO:BP
# 175  3.226027e-02  GO:0072006  GO:BP
# 176  3.943211e-02  GO:0003676  GO:MF
# 177  4.996161e-02  GO:0090571  GO:CC
#
#                                              term_name
# 0                                     limb development
# 1                                appendage development
# 2                              appendage morphogenesis
# 3                                   limb morphogenesis
# 4                    embryonic appendage morphogenesis
# ..                                                 ...
# 173    cellular nitrogen compound biosynthetic process
# 174                           myoblast differentiation
# 175                                nephron development
# 176                               nucleic acid binding
# 177  RNA polymerase II transcription repressor complex
#
# [178 rows x 4 columns]

# %%
# read BEHST limb output GO terms
limb = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/bin/BEHST-results/vista_LIMB_sorted_bed_gProfiler_results_QUERY28000_TARGET18100_revGO_term_list_rand1591227782.behst", 
                   sep='\t', header=0)

limb_res = merge_df(limb, limb_ref, ['term_id', 'source', 'term_name'], True)
limb_res[0]
# Out:
# The number of true positive terms is 58
# The number of false positive terms is 2
#        p_value_x     term_id source  \
# 0   1.150596e-10  GO:0001501  GO:BP
# 1   2.388447e-09  GO:0048598  GO:BP
# 2   5.034933e-08  GO:0048568  GO:BP
# 3   1.895330e-07  GO:0048562  GO:BP
# 4   3.258574e-07  GO:0003002  GO:BP
# 5   1.151070e-06  GO:0009952  GO:BP
# 6   1.785529e-06  GO:0009790  GO:BP
# 7   1.796065e-06  GO:0048706  GO:BP
# 8   2.147059e-06  GO:0000981  GO:MF
# 9   2.480959e-06  GO:0007389  GO:BP
# 10  5.335762e-06  GO:0048705  GO:BP
# 11  1.740721e-05  GO:0048704  GO:BP
# 12  3.346897e-05  GO:0003700  GO:MF
# 13  6.192042e-05  GO:0009887  GO:BP
# 14  6.353144e-05  GO:0000978  GO:MF
# 15  6.355622e-05  GO:0043565  GO:MF
# 16  1.149512e-04  GO:0000790  GO:CC
# 17  1.194424e-04  GO:0035108  GO:BP
# 18  1.194424e-04  GO:0035107  GO:BP
# 19  1.250117e-04  GO:0000987  GO:MF
# 20  1.454074e-04  GO:0035326  GO:MF
# 21  1.703312e-04  GO:1990837  GO:MF
# 22  2.631167e-04  GO:0003690  GO:MF
# 23  2.721978e-04  GO:0000976  GO:MF
# 24  3.822497e-04  GO:0000977  GO:MF
# 25  4.418022e-04  GO:0001012  GO:MF
# 26  4.587079e-04  GO:0010628  GO:BP
# 27  6.052586e-04  GO:0044212  GO:MF
# 28  6.164304e-04  GO:0001067  GO:MF
# 29  6.630415e-04  GO:0000785  GO:CC
# 30  7.525704e-04  GO:0060173  GO:BP
# 31  7.525704e-04  GO:0048736  GO:BP
# 32  1.232277e-03  GO:0009653  GO:BP
# 33  1.384855e-03  GO:0000228  GO:CC
# 34  1.515828e-03  GO:0140110  GO:MF
# 35  1.687462e-03  GO:0006357  GO:BP
# 36  1.903866e-03  GO:0045944  GO:BP
# 37  2.651623e-03  GO:0030326  GO:BP
# 38  2.651623e-03  GO:0035113  GO:BP
# 39  3.148980e-03  GO:0045893  GO:BP
# 40  4.188736e-03  GO:1903508  GO:BP
# 41  4.244546e-03  GO:1902680  GO:BP
# 42  4.776715e-03  GO:0045935  GO:BP
# 43  4.812972e-03  GO:0051254  GO:BP
# 44  6.676469e-03  GO:0005694  GO:CC
# 45  9.517928e-03  GO:0006366  GO:BP
# 46  1.617706e-02  GO:0010557  GO:BP
# 48  1.835446e-02  GO:0031328  GO:BP
# 49  2.031474e-02  GO:0009954  GO:BP
# 50  2.657806e-02  GO:0009891  GO:BP
# 51  3.036320e-02  GO:0009792  GO:BP
# 52  3.288584e-02  GO:0097659  GO:BP
# 53  3.661951e-02  GO:0001228  GO:MF
# 54  3.672967e-02  GO:0032774  GO:BP
# 55  3.928923e-02  GO:0001216  GO:MF
# 56  4.515087e-02  GO:1903506  GO:BP
# 57  4.697711e-02  GO:2001141  GO:BP
# 58  4.961821e-02  GO:0006351  GO:BP
#
#                                                                    term_name  \
# 0                                                skeletal system development
# 1                                                    embryonic morphogenesis
# 2                                                embryonic organ development
# 3                                              embryonic organ morphogenesis
# 4                                                            regionalization
# 5                                   anterior/posterior pattern specification
# 6                                                         embryo development
# 7                                      embryonic skeletal system development
# 8      DNA-binding transcription factor activity, RNA polymerase II-specific
# 9                                              pattern specification process
# 10                                             skeletal system morphogenesis
# 11                                   embryonic skeletal system morphogenesis
# 12                                 DNA-binding transcription factor activity
# 13                                                animal organ morphogenesis
# 14     RNA polymerase II cis-regulatory region sequence-specific DNA binding
# 15                                             sequence-specific DNA binding
# 16                                                         nuclear chromatin
# 17                                                        limb morphogenesis
# 18                                                   appendage morphogenesis
# 19                       cis-regulatory region sequence-specific DNA binding
# 20                                             cis-regulatory region binding
# 21                             sequence-specific double-stranded DNA binding
# 22                                               double-stranded DNA binding
# 23             transcription regulatory region sequence-specific DNA binding
# 24         RNA polymerase II regulatory region sequence-specific DNA binding
# 25                           RNA polymerase II regulatory region DNA binding
# 26                                    positive regulation of gene expression
# 27                               transcription regulatory region DNA binding
# 28                                    regulatory region nucleic acid binding
# 29                                                                 chromatin
# 30                                                          limb development
# 31                                                     appendage development
# 32                                        anatomical structure morphogenesis
# 33                                                        nuclear chromosome
# 34                                          transcription regulator activity
# 35                          regulation of transcription by RNA polymerase II
# 36                 positive regulation of transcription by RNA polymerase II
# 37                                              embryonic limb morphogenesis
# 38                                         embryonic appendage morphogenesis
# 39                       positive regulation of transcription, DNA-templated
# 40               positive regulation of nucleic acid-templated transcription
# 41                           positive regulation of RNA biosynthetic process
# 42   positive regulation of nucleobase-containing compound metabolic process
# 43                              positive regulation of RNA metabolic process
# 44                                                                chromosome
# 45                                        transcription by RNA polymerase II
# 46                 positive regulation of macromolecule biosynthetic process
# 48                      positive regulation of cellular biosynthetic process
# 49                                         proximal/distal pattern formation
# 50                               positive regulation of biosynthetic process
# 51                        embryo development ending in birth or egg hatching
# 52                                      nucleic acid-templated transcription
# 53  DNA-binding transcription activator activity, RNA polymerase II-specific
# 54                                                  RNA biosynthetic process
# 55                              DNA-binding transcription activator activity
# 56                        regulation of nucleic acid-templated transcription
# 57                                    regulation of RNA biosynthetic process
# 58                                              transcription, DNA-templated
#
#        p_value_y _merge
# 0   1.423548e-19   both
# 1   1.207525e-15   both
# 2   1.529934e-04   both
# 3   2.089487e-06   both
# 4   1.752402e-11   both
# 5   5.286603e-08   both
# 6   3.135152e-12   both
# 7   2.814358e-09   both
# 8   1.388936e-15   both
# 9   1.859436e-13   both
# 10  3.916719e-14   both
# 11  4.630908e-09   both
# 12  7.006285e-14   both
# 13  6.804185e-12   both
# 14  1.188419e-05   both
# 15  7.987161e-13   both
# 16  1.702319e-14   both
# 17  5.502065e-23   both
# 18  5.502065e-23   both
# 19  2.005722e-05   both
# 20  2.255280e-05   both
# 21  1.382682e-09   both
# 22  8.612231e-09   both
# 23  5.224864e-10   both
# 24  1.614064e-10   both
# 25  1.905652e-10   both
# 26  5.371021e-08   both
# 27  5.240397e-09   both
# 28  5.342985e-09   both
# 29  8.290435e-13   both
# 30  1.520378e-26   both
# 31  1.520378e-26   both
# 32  2.937630e-13   both
# 33  2.181910e-12   both
# 34  9.129339e-11   both
# 35  1.969506e-09   both
# 36  2.383907e-06   both
# 37  1.153630e-22   both
# 38  1.153630e-22   both
# 39  9.756148e-07   both
# 40  3.459089e-06   both
# 41  3.501480e-06   both
# 42  5.858566e-05   both
# 43  1.011132e-05   both
# 44  2.919854e-09   both
# 45  1.246135e-08   both
# 46  1.415997e-05   both
# 48  7.458029e-06   both
# 49  9.709667e-12   both
# 50  1.063561e-05   both
# 51  4.288060e-06   both
# 52  7.659882e-05   both
# 53  1.304658e-08   both
# 54  8.441958e-05   both
# 55  1.437720e-08   both
# 56  2.503299e-05   both
# 57  2.597328e-05   both
# 58  5.545471e-05   both

# %%
limb_res[1]
# Out:
#     p_value_x     term_id source  \
# 47   0.018272  GO:0002095  GO:CC
# 59   0.049652  GO:1902379  GO:MF
#
#                                              term_name  p_value_y     _merge
# 47           caveolar macromolecular signaling complex        NaN  left_only
# 59  chemoattractant activity involved in axon guidance        NaN  left_only

# %% [markdown]
# ### Comparison with total shuffling and tss shuffling
# #### limb total

# %%
limb_total = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/vista_LIMB_SHUFFLED/gprofiler2_output/vista_LIMB_SHUFFLED_bed_QUERY28000_TARGET18100_gprofiler_output", 
                   sep='\t', header=0)

limb_total = limb_total[['p_value', 'term_id', 'source', 'term_name']]
limb_total = limb_total[limb_total['p_value'] <= 0.05]
len(limb_total)
# Out:
# 30

# %%
# intersect with reference
limb_total_res = merge_df(limb_total, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 1
# The number of false positive terms is 29

# %%
limb_total_res[0]
# Out:
#     p_value_x     term_id source           term_name     p_value_y _merge
# 10   0.002825  GO:0009888  GO:BP  tissue development  5.856012e-11   both

# %%
limb_total_res[1]
# Out:
#        p_value_x     term_id source  \
# 0   6.026773e-08  GO:0070268  GO:BP
# 1   1.333986e-06  GO:0031424  GO:BP
# 2   2.874554e-06  GO:0030216  GO:BP
# 3   5.313839e-05  GO:0009913  GO:BP
# 4   3.998853e-04  GO:0010896  GO:BP
# 5   5.903601e-04  GO:0043588  GO:BP
# 6   6.546098e-04  GO:0090207  GO:BP
# 7   8.311337e-04  GO:0008544  GO:BP
# 8   1.687502e-03  GO:0030855  GO:BP
# 9   2.042889e-03  GO:0010898  GO:BP
# 11  6.392204e-03  GO:0055090  GO:BP
# 12  6.392204e-03  GO:0070328  GO:BP
# 13  9.377784e-03  GO:0034372  GO:BP
# 14  1.394250e-02  GO:0033700  GO:BP
# 15  1.996144e-02  GO:0034370  GO:BP
# 16  2.675356e-02  GO:0010901  GO:BP
# 17  3.490505e-08  GO:0045111  GO:CC
# 18  1.866965e-07  GO:0005882  GO:CC
# 19  5.663949e-03  GO:0042627  GO:CC
# 20  8.959984e-03  GO:0031982  GO:CC
# 21  9.093865e-03  GO:0005615  GO:CC
# 22  1.408787e-02  GO:1903561  GO:CC
# 23  1.490462e-02  GO:0043230  GO:CC
# 24  2.325824e-02  GO:0070062  GO:CC
# 25  3.182618e-02  GO:0034385  GO:CC
# 26  3.182618e-02  GO:0034361  GO:CC
# 27  3.696361e-02  GO:0005576  GO:CC
# 28  1.146902e-02  GO:0060228  GO:MF
# 29  3.988741e-02  GO:0004867  GO:MF
#
#                                                           term_name  \
# 0                                                     cornification
# 1                                                    keratinization
# 2                                      keratinocyte differentiation
# 3                                    epidermal cell differentiation
# 4                      regulation of triglyceride catabolic process
# 5                                                  skin development
# 6                      regulation of triglyceride metabolic process
# 7                                             epidermis development
# 8                                   epithelial cell differentiation
# 9             positive regulation of triglyceride catabolic process
# 11                                         acylglycerol homeostasis
# 12                                         triglyceride homeostasis
# 13                 very-low-density lipoprotein particle remodeling
# 14                                              phospholipid efflux
# 15                triglyceride-rich lipoprotein particle remodeling
# 16   regulation of very-low-density lipoprotein particle remodeling
# 17                               intermediate filament cytoskeleton
# 18                                            intermediate filament
# 19                                                      chylomicron
# 20                                                          vesicle
# 21                                              extracellular space
# 22                                            extracellular vesicle
# 23                                          extracellular organelle
# 24                                            extracellular exosome
# 25                    triglyceride-rich plasma lipoprotein particle
# 26                            very-low-density lipoprotein particle
# 27                                             extracellular region
# 28  phosphatidylcholine-sterol O-acyltransferase activator activity
# 29                     serine-type endopeptidase inhibitor activity
#
#     p_value_y     _merge
# 0         NaN  left_only
# 1         NaN  left_only
# 2         NaN  left_only
# 3         NaN  left_only
# 4         NaN  left_only
# 5         NaN  left_only
# 6         NaN  left_only
# 7         NaN  left_only
# 8         NaN  left_only
# 9         NaN  left_only
# 11        NaN  left_only
# 12        NaN  left_only
# 13        NaN  left_only
# 14        NaN  left_only
# 15        NaN  left_only
# 16        NaN  left_only
# 17        NaN  left_only
# 18        NaN  left_only
# 19        NaN  left_only
# 20        NaN  left_only
# 21        NaN  left_only
# 22        NaN  left_only
# 23        NaN  left_only
# 24        NaN  left_only
# 25        NaN  left_only
# 26        NaN  left_only
# 27        NaN  left_only
# 28        NaN  left_only
# 29        NaN  left_only

# %% [markdown]
# #### limb tss

# %%
limb_tss = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/randomlyShuffledChromWide_vista_LIMB_sorted/gprofiler2_output/randomlyShuffledChromWide_vista_LIMB_sorted_bed_QUERY28000_TARGET18100_gprofiler_output", 
                   sep='\t', header=0)

limb_tss = limb_tss[['p_value', 'term_id', 'source', 'term_name']]
limb_tss = limb_tss[limb_tss['p_value'] <= 0.05]
len(limb_tss)
# Out:
# 10

# %%
# intersect with reference
limb_tss_res = merge_df(limb_tss, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 0
# The number of false positive terms is 10

# %%
limb_tss_res[1]
# Out:
#    p_value_x     term_id source  \
# 0   0.035037  GO:0070098  GO:BP
# 1   0.000026  GO:0016493  GO:MF
# 2   0.000035  GO:0019957  GO:MF
# 3   0.000059  GO:0001637  GO:MF
# 4   0.000059  GO:0004950  GO:MF
# 5   0.000270  GO:0019956  GO:MF
# 6   0.032747  GO:0008528  GO:MF
# 7   0.043529  GO:0001653  GO:MF
# 8   0.049614  GO:0035717  GO:MF
# 9   0.049614  GO:0071791  GO:MF
#
#                                              term_name  p_value_y     _merge
# 0                 chemokine-mediated signaling pathway        NaN  left_only
# 1                      C-C chemokine receptor activity        NaN  left_only
# 2                                C-C chemokine binding        NaN  left_only
# 3  G protein-coupled chemoattractant receptor activity        NaN  left_only
# 4                          chemokine receptor activity        NaN  left_only
# 5                                    chemokine binding        NaN  left_only
# 6          G protein-coupled peptide receptor activity        NaN  left_only
# 7                            peptide receptor activity        NaN  left_only
# 8               chemokine (C-C motif) ligand 7 binding        NaN  left_only
# 9               chemokine (C-C motif) ligand 5 binding        NaN  left_only

# %% [markdown]
# ### Worst parameters

# %% [markdown]
# - From the summation matrix, the worst parameters are query extension = 100, target extension = 6100
# - From the VISTA limb data, the worst parameters are query extension = 3200, target extension = 3100
# - From the VISTA limb data, the best parameters are query extension = 9400, target extension = 6100

# %% [markdown]
# ### Query extension = 100, Target extension = 100

# %%
limb_100_100 = pd.read_csv("../BEHST/results/07-07/vista_LIMB_sorted_100_100_go_list", sep='\t', header=0)

# %%
limb_100_100_res = merge_df(limb_100_100, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 41
# The number of false positive terms is 1

# %%
top_50_100_100 = top_50(limb_100_100, limb_ref)
# Out:
# The number of true positive terms is 47
# The number of false positive terms is 3

# %% [markdown]
# ### Query extension = 3200, Target extension = 3100

# %%
limb_3200_3100 = pd.read_csv("../BEHST/results/07-07/vista_LIMB_sorted_3200_3100_go_list", sep='\t', header=0)

# %%
limb_3200_3100_res = merge_df(limb_3200_3100, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 41
# The number of false positive terms is 1

# %%
top_50_3200_3100 = top_50(limb_3200_3100, limb_ref)
# Out:
# The number of true positive terms is 49
# The number of false positive terms is 1

# %% [markdown]
# ### Query extension = 100, Target extension = 6100 (Worst Parameter)

# %%
limb_100_6100 = pd.read_csv("../BEHST/results/07-07/vista_LIMB_sorted_100_6100_go_list", sep='\t', header=0)

limb_100_6100_res = merge_df(limb_100_6100, limb_ref, ['term_id', 'source', 'term_name'], True)
limb_100_6100_res[0]
# Out:
# The number of true positive terms is 51
# The number of false positive terms is 2
#        p_value_x     term_id source  \
# 0   4.196831e-09  GO:0048562  GO:BP
# 1   2.048691e-08  GO:0048568  GO:BP
# 2   6.303988e-08  GO:0048598  GO:BP
# 3   8.141268e-08  GO:0048704  GO:BP
# 4   2.441219e-07  GO:0000981  GO:MF
# 5   7.010824e-07  GO:0003700  GO:MF
# 6   8.146066e-07  GO:0048706  GO:BP
# 7   2.507476e-06  GO:0009952  GO:BP
# 8   2.866713e-06  GO:0001501  GO:BP
# 9   4.550185e-06  GO:0140110  GO:MF
# 10  6.657129e-06  GO:0048705  GO:BP
# 11  1.884577e-05  GO:0043565  GO:MF
# 12  8.316038e-05  GO:0009790  GO:BP
# 13  1.056136e-04  GO:0000978  GO:MF
# 14  1.554288e-04  GO:0000987  GO:MF
# 15  1.557581e-04  GO:0003690  GO:MF
# 16  1.566155e-04  GO:0003002  GO:BP
# 17  1.625453e-04  GO:0000977  GO:MF
# 18  1.695025e-04  GO:0035326  GO:MF
# 19  1.770921e-04  GO:0001012  GO:MF
# 20  1.796962e-04  GO:0006357  GO:BP
# 21  2.980335e-04  GO:0000976  GO:MF
# 22  3.102974e-04  GO:0000785  GO:CC
# 23  4.008286e-04  GO:0000790  GO:CC
# 24  4.924437e-04  GO:1990837  GO:MF
# 25  5.291875e-04  GO:0006366  GO:BP
# 26  9.791979e-04  GO:0044212  GO:MF
# 27  9.890389e-04  GO:0001067  GO:MF
# 28  1.081703e-03  GO:0003677  GO:MF
# 29  1.109990e-03  GO:0007389  GO:BP
# 30  2.100794e-03  GO:0009954  GO:BP
# 31  3.024431e-03  GO:0000228  GO:CC
# 32  3.180130e-03  GO:0045944  GO:BP
# 33  6.099982e-03  GO:0051254  GO:BP
# 34  6.832826e-03  GO:0009653  GO:BP
# 35  6.934868e-03  GO:0009887  GO:BP
# 36  8.453340e-03  GO:0045893  GO:BP
# 37  9.904784e-03  GO:0001228  GO:MF
# 38  1.035199e-02  GO:0001216  GO:MF
# 39  1.261807e-02  GO:0005694  GO:CC
# 40  1.748247e-02  GO:1903508  GO:BP
# 41  1.760511e-02  GO:1902680  GO:BP
# 42  1.840978e-02  GO:0045935  GO:BP
# 43  1.878876e-02  GO:0035113  GO:BP
# 44  1.878876e-02  GO:0030326  GO:BP
# 45  2.490037e-02  GO:0043009  GO:BP
# 47  3.087644e-02  GO:0009792  GO:BP
# 49  4.180858e-02  GO:0035107  GO:BP
# 50  4.180858e-02  GO:0035108  GO:BP
# 51  4.418251e-02  GO:0010628  GO:BP
# 52  4.553753e-02  GO:0006355  GO:BP
#
#                                                                    term_name  \
# 0                                              embryonic organ morphogenesis
# 1                                                embryonic organ development
# 2                                                    embryonic morphogenesis
# 3                                    embryonic skeletal system morphogenesis
# 4      DNA-binding transcription factor activity, RNA polymerase II-specific
# 5                                  DNA-binding transcription factor activity
# 6                                      embryonic skeletal system development
# 7                                   anterior/posterior pattern specification
# 8                                                skeletal system development
# 9                                           transcription regulator activity
# 10                                             skeletal system morphogenesis
# 11                                             sequence-specific DNA binding
# 12                                                        embryo development
# 13     RNA polymerase II cis-regulatory region sequence-specific DNA binding
# 14                       cis-regulatory region sequence-specific DNA binding
# 15                                               double-stranded DNA binding
# 16                                                           regionalization
# 17         RNA polymerase II regulatory region sequence-specific DNA binding
# 18                                             cis-regulatory region binding
# 19                           RNA polymerase II regulatory region DNA binding
# 20                          regulation of transcription by RNA polymerase II
# 21             transcription regulatory region sequence-specific DNA binding
# 22                                                                 chromatin
# 23                                                         nuclear chromatin
# 24                             sequence-specific double-stranded DNA binding
# 25                                        transcription by RNA polymerase II
# 26                               transcription regulatory region DNA binding
# 27                                    regulatory region nucleic acid binding
# 28                                                               DNA binding
# 29                                             pattern specification process
# 30                                         proximal/distal pattern formation
# 31                                                        nuclear chromosome
# 32                 positive regulation of transcription by RNA polymerase II
# 33                              positive regulation of RNA metabolic process
# 34                                        anatomical structure morphogenesis
# 35                                                animal organ morphogenesis
# 36                       positive regulation of transcription, DNA-templated
# 37  DNA-binding transcription activator activity, RNA polymerase II-specific
# 38                              DNA-binding transcription activator activity
# 39                                                                chromosome
# 40               positive regulation of nucleic acid-templated transcription
# 41                           positive regulation of RNA biosynthetic process
# 42   positive regulation of nucleobase-containing compound metabolic process
# 43                                         embryonic appendage morphogenesis
# 44                                              embryonic limb morphogenesis
# 45                                            chordate embryonic development
# 47                        embryo development ending in birth or egg hatching
# 49                                                   appendage morphogenesis
# 50                                                        limb morphogenesis
# 51                                    positive regulation of gene expression
# 52                                regulation of transcription, DNA-templated
#
#        p_value_y _merge
# 0   2.089487e-06   both
# 1   1.529934e-04   both
# 2   1.207525e-15   both
# 3   4.630908e-09   both
# 4   1.388936e-15   both
# 5   7.006285e-14   both
# 6   2.814358e-09   both
# 7   5.286603e-08   both
# 8   1.423548e-19   both
# 9   9.129339e-11   both
# 10  3.916719e-14   both
# 11  7.987161e-13   both
# 12  3.135152e-12   both
# 13  1.188419e-05   both
# 14  2.005722e-05   both
# 15  8.612231e-09   both
# 16  1.752402e-11   both
# 17  1.614064e-10   both
# 18  2.255280e-05   both
# 19  1.905652e-10   both
# 20  1.969506e-09   both
# 21  5.224864e-10   both
# 22  8.290435e-13   both
# 23  1.702319e-14   both
# 24  1.382682e-09   both
# 25  1.246135e-08   both
# 26  5.240397e-09   both
# 27  5.342985e-09   both
# 28  1.765194e-07   both
# 29  1.859436e-13   both
# 30  9.709667e-12   both
# 31  2.181910e-12   both
# 32  2.383907e-06   both
# 33  1.011132e-05   both
# 34  2.937630e-13   both
# 35  6.804185e-12   both
# 36  9.756148e-07   both
# 37  1.304658e-08   both
# 38  1.437720e-08   both
# 39  2.919854e-09   both
# 40  3.459089e-06   both
# 41  3.501480e-06   both
# 42  5.858566e-05   both
# 43  1.153630e-22   both
# 44  1.153630e-22   both
# 45  2.907179e-06   both
# 47  4.288060e-06   both
# 49  5.502065e-23   both
# 50  5.502065e-23   both
# 51  5.371021e-08   both
# 52  1.471612e-05   both

# %%
limb_100_6100_res[1]
# Out:
#     p_value_x     term_id source                term_name  p_value_y  \
# 46   0.029729  GO:0060065  GO:BP       uterus development        NaN
# 48   0.036276  GO:0042101  GO:CC  T cell receptor complex        NaN
#
#        _merge
# 46  left_only
# 48  left_only

# %%
top_50_100_6100 = top_50(limb_100_6100, limb_ref)
# Out:
# The number of true positive terms is 48
# The number of false positive terms is 2

# %% [markdown]
# ### Query extension = 9400, Target extension = 6100

# %%
limb_9400_6100 = pd.read_csv("../BEHST/results/07-07/vista_LIMB_sorted_9400_6100_go_list", sep='\t', header=0)

limb_9400_6100_res = merge_df(limb_9400_6100, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 75
# The number of false positive terms is 2

# %%
top_50_9400_6100 = top_50(limb_9400_6100, limb_ref)
# Out:
# The number of true positive terms is 50
# The number of false positive terms is 0

# %%
# check overlapped terms

limb_100_6100_pos = limb_100_6100_res[0][['p_value_x', 'term_id', 'source', 'term_name']]
limb_pos = limb_res[0][['p_value_x', 'term_id', 'source', 'term_name']]
merged = merge_df(limb_100_6100_pos, limb_pos, ['term_id', 'source', 'term_name'], True)
merged[0]
# Out:
# The number of true positive terms is 48
# The number of false positive terms is 3
#      p_value_x_x     term_id source  \
# 0   4.196831e-09  GO:0048562  GO:BP
# 1   2.048691e-08  GO:0048568  GO:BP
# 2   6.303988e-08  GO:0048598  GO:BP
# 3   8.141268e-08  GO:0048704  GO:BP
# 4   2.441219e-07  GO:0000981  GO:MF
# 5   7.010824e-07  GO:0003700  GO:MF
# 6   8.146066e-07  GO:0048706  GO:BP
# 7   2.507476e-06  GO:0009952  GO:BP
# 8   2.866713e-06  GO:0001501  GO:BP
# 9   4.550185e-06  GO:0140110  GO:MF
# 10  6.657129e-06  GO:0048705  GO:BP
# 11  1.884577e-05  GO:0043565  GO:MF
# 12  8.316038e-05  GO:0009790  GO:BP
# 13  1.056136e-04  GO:0000978  GO:MF
# 14  1.554288e-04  GO:0000987  GO:MF
# 15  1.557581e-04  GO:0003690  GO:MF
# 16  1.566155e-04  GO:0003002  GO:BP
# 17  1.625453e-04  GO:0000977  GO:MF
# 18  1.695025e-04  GO:0035326  GO:MF
# 19  1.770921e-04  GO:0001012  GO:MF
# 20  1.796962e-04  GO:0006357  GO:BP
# 21  2.980335e-04  GO:0000976  GO:MF
# 22  3.102974e-04  GO:0000785  GO:CC
# 23  4.008286e-04  GO:0000790  GO:CC
# 24  4.924437e-04  GO:1990837  GO:MF
# 25  5.291875e-04  GO:0006366  GO:BP
# 26  9.791979e-04  GO:0044212  GO:MF
# 27  9.890389e-04  GO:0001067  GO:MF
# 29  1.109990e-03  GO:0007389  GO:BP
# 30  2.100794e-03  GO:0009954  GO:BP
# 31  3.024431e-03  GO:0000228  GO:CC
# 32  3.180130e-03  GO:0045944  GO:BP
# 33  6.099982e-03  GO:0051254  GO:BP
# 34  6.832826e-03  GO:0009653  GO:BP
# 35  6.934868e-03  GO:0009887  GO:BP
# 36  8.453340e-03  GO:0045893  GO:BP
# 37  9.904784e-03  GO:0001228  GO:MF
# 38  1.035199e-02  GO:0001216  GO:MF
# 39  1.261807e-02  GO:0005694  GO:CC
# 40  1.748247e-02  GO:1903508  GO:BP
# 41  1.760511e-02  GO:1902680  GO:BP
# 42  1.840978e-02  GO:0045935  GO:BP
# 43  1.878876e-02  GO:0035113  GO:BP
# 44  1.878876e-02  GO:0030326  GO:BP
# 46  3.087644e-02  GO:0009792  GO:BP
# 47  4.180858e-02  GO:0035107  GO:BP
# 48  4.180858e-02  GO:0035108  GO:BP
# 49  4.418251e-02  GO:0010628  GO:BP
#
#                                                                    term_name  \
# 0                                              embryonic organ morphogenesis
# 1                                                embryonic organ development
# 2                                                    embryonic morphogenesis
# 3                                    embryonic skeletal system morphogenesis
# 4      DNA-binding transcription factor activity, RNA polymerase II-specific
# 5                                  DNA-binding transcription factor activity
# 6                                      embryonic skeletal system development
# 7                                   anterior/posterior pattern specification
# 8                                                skeletal system development
# 9                                           transcription regulator activity
# 10                                             skeletal system morphogenesis
# 11                                             sequence-specific DNA binding
# 12                                                        embryo development
# 13     RNA polymerase II cis-regulatory region sequence-specific DNA binding
# 14                       cis-regulatory region sequence-specific DNA binding
# 15                                               double-stranded DNA binding
# 16                                                           regionalization
# 17         RNA polymerase II regulatory region sequence-specific DNA binding
# 18                                             cis-regulatory region binding
# 19                           RNA polymerase II regulatory region DNA binding
# 20                          regulation of transcription by RNA polymerase II
# 21             transcription regulatory region sequence-specific DNA binding
# 22                                                                 chromatin
# 23                                                         nuclear chromatin
# 24                             sequence-specific double-stranded DNA binding
# 25                                        transcription by RNA polymerase II
# 26                               transcription regulatory region DNA binding
# 27                                    regulatory region nucleic acid binding
# 29                                             pattern specification process
# 30                                         proximal/distal pattern formation
# 31                                                        nuclear chromosome
# 32                 positive regulation of transcription by RNA polymerase II
# 33                              positive regulation of RNA metabolic process
# 34                                        anatomical structure morphogenesis
# 35                                                animal organ morphogenesis
# 36                       positive regulation of transcription, DNA-templated
# 37  DNA-binding transcription activator activity, RNA polymerase II-specific
# 38                              DNA-binding transcription activator activity
# 39                                                                chromosome
# 40               positive regulation of nucleic acid-templated transcription
# 41                           positive regulation of RNA biosynthetic process
# 42   positive regulation of nucleobase-containing compound metabolic process
# 43                                         embryonic appendage morphogenesis
# 44                                              embryonic limb morphogenesis
# 46                        embryo development ending in birth or egg hatching
# 47                                                   appendage morphogenesis
# 48                                                        limb morphogenesis
# 49                                    positive regulation of gene expression
#
#      p_value_x_y _merge
# 0   1.895330e-07   both
# 1   5.034933e-08   both
# 2   2.388447e-09   both
# 3   1.740721e-05   both
# 4   2.147059e-06   both
# 5   3.346897e-05   both
# 6   1.796065e-06   both
# 7   1.151070e-06   both
# 8   1.150596e-10   both
# 9   1.515828e-03   both
# 10  5.335762e-06   both
# 11  6.355622e-05   both
# 12  1.785529e-06   both
# 13  6.353144e-05   both
# 14  1.250117e-04   both
# 15  2.631167e-04   both
# 16  3.258574e-07   both
# 17  3.822497e-04   both
# 18  1.454074e-04   both
# 19  4.418022e-04   both
# 20  1.687462e-03   both
# 21  2.721978e-04   both
# 22  6.630415e-04   both
# 23  1.149512e-04   both
# 24  1.703312e-04   both
# 25  9.517928e-03   both
# 26  6.052586e-04   both
# 27  6.164304e-04   both
# 29  2.480959e-06   both
# 30  2.031474e-02   both
# 31  1.384855e-03   both
# 32  1.903866e-03   both
# 33  4.812972e-03   both
# 34  1.232277e-03   both
# 35  6.192042e-05   both
# 36  3.148980e-03   both
# 37  3.661951e-02   both
# 38  3.928923e-02   both
# 39  6.676469e-03   both
# 40  4.188736e-03   both
# 41  4.244546e-03   both
# 42  4.776715e-03   both
# 43  2.651623e-03   both
# 44  2.651623e-03   both
# 46  3.036320e-02   both
# 47  1.194424e-04   both
# 48  1.194424e-04   both
# 49  4.587079e-04   both

# %%
merged[1]
# Out:
#     p_value_x_x     term_id source  \
# 28     0.001082  GO:0003677  GO:MF
# 45     0.024900  GO:0043009  GO:BP
# 50     0.045538  GO:0006355  GO:BP
#
#                                      term_name  p_value_x_y     _merge
# 28                                 DNA binding          NaN  left_only
# 45              chordate embryonic development          NaN  left_only
# 50  regulation of transcription, DNA-templated          NaN  left_only

# %% [markdown]
# ### Conclusion
# - Optimized parameters return a larger number of significant GO terms. The number of false positive terms is similar from inquiries using different parameters, so the precision using optimized parameters is higher.

# %% [markdown]
# ## Reference GO list from all tissues

# %%
all_ave = calculate_mean([limb_1, limb_2, forebrain_1, forebrain_2, midbrain_1, midbrain_2, 
                          hindbrain_1, hindbrain_2, 
                       heart_1, heart_2, liver_1, liver_2, neural_tube_1, neural_tube_2, facial_1, facial_2])

all_ave = all_ave[all_ave.pme_TPM >= 1]
all_ave['gene_id'] = all_ave['gene_id'].str.split('.').str.get(0)

# number of expressed genes
len(all_ave)
# Out:
# 18704

# %%
all_mapped = pd.merge(all_ave, gene_ids, on='gene_id', how='inner')

# number of mapped genes
len(all_mapped)
# Out:
# 14897

# %%
# all_mapped[['Gene stable ID']].to_csv('../BEHST/data/06_24_reference_gene_id_all', header=None, index=None)

# %%
all_ref = pd.read_csv("../BEHST/results/06-24/go_list_all", sep="\t", header=0)
all_ref = all_ref[all_ref.p_value <= 0.05]
all_ref
# Out:
#             p_value     term_id source  \
# 0     4.940656e-324  GO:0043231  GO:CC
# 1     4.940656e-324  GO:0043227  GO:CC
# 2     4.940656e-324  GO:0005622  GO:CC
# 3     4.940656e-324  GO:0005737  GO:CC
# 4     4.940656e-324  GO:0043226  GO:CC
# ...             ...         ...    ...
# 1913   4.925656e-02  GO:0006904  GO:BP
# 1914   4.925656e-02  GO:0051985  GO:BP
# 1915   4.925656e-02  GO:0021575  GO:BP
# 1916   4.925656e-02  GO:0051293  GO:BP
# 1917   4.994531e-02  GO:0009055  GO:MF
#
#                                           term_name
# 0          intracellular membrane-bounded organelle
# 1                        membrane-bounded organelle
# 2                                     intracellular
# 3                                         cytoplasm
# 4                                         organelle
# ...                                             ...
# 1913         vesicle docking involved in exocytosis
# 1914  negative regulation of chromosome segregation
# 1915                        hindbrain morphogenesis
# 1916          establishment of spindle localization
# 1917                     electron transfer activity
#
# [1918 rows x 4 columns]

# %% [markdown]
# ## GREAT: intersect with significant terms in reference list

# %% [markdown]
# #### result downloaded from GREAT web query
# Test set:
# vista_LIMB_sorted_EDITED_FOR_GREAT.bed (243 genomic regions)
#
# Background:
# Whole genome background
#
# Assembly:
# Human: GRCh37 (UCSC hg19, Feb. 2009)
#
# Associated genomic regions:
# Basal+extension (constitutive 5.0 kb upstream and 1.0 kb downstream, up to 1000.0 kb max extension). Curated regulatory domains are included.
# 6 of all 243 genomic regions (2.5%) are not associated with any genes.
#
# Statistical significance: FDR
# threshold: 0.05
# View: siginificant by both

# %% [markdown]
# ### FDR

# %%
limb_great = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/06-12/06-12-shown-MultipleOntologies.tsv", sep='\t', header=1)
limb_great = limb_great.reset_index()
#limb_great = limb_great[['index', '# Ontology', ' Term Name ', ' Binom Raw P-Value ', '  Binom FDR Q-Val  ', 
#                         '  Hyper FDR Q-Val  ']]
limb_great = limb_great[['index', '# Ontology', ' Term Name ', ' Binom Rank ',
                         ' Binom Raw P-Value ', ' Hyper Rank ']]
limb_great.columns = ['ontology', 'term name', 'term_id', 'binom_raw_p_value', 'binom_FDR_q_value',
                      'hyper_FDR_q_value']

# %%
great_res = merge_df(limb_great[['ontology', 'term_id', 'binom_raw_p_value', 'term name']], limb_ref, ['term_id'], 
                     True)
great_res[0][['term_id', 'binom_raw_p_value', 'term_name', 'p_value', 'source', '_merge']]
# Out:
# The number of true positive terms is 8
# The number of false positive terms is 18
#        term_id  binom_raw_p_value  \
# 8   GO:0035295       3.963168e-10
# 11  GO:0048598       8.090736e-10
# 14  GO:0048562       1.067187e-08
# 15  GO:0048568       1.181012e-08
# 17  GO:0009790       2.616653e-08
# 19  GO:0035239       5.610827e-08
# 20  GO:0003700       1.689470e-09
# 21  GO:0000981       1.177067e-07
#
#                                                                 term_name  \
# 8                                                        tube development
# 11                                                embryonic morphogenesis
# 14                                          embryonic organ morphogenesis
# 15                                            embryonic organ development
# 17                                                     embryo development
# 19                                                     tube morphogenesis
# 20                              DNA-binding transcription factor activity
# 21  DNA-binding transcription factor activity, RNA polymerase II-specific
#
#          p_value source _merge
# 8   1.142134e-03  GO:BP   both
# 11  1.207525e-15  GO:BP   both
# 14  2.089487e-06  GO:BP   both
# 15  1.529934e-04  GO:BP   both
# 17  3.135152e-12  GO:BP   both
# 19  1.439291e-02  GO:BP   both
# 20  7.006285e-14  GO:MF   both
# 21  1.388936e-15  GO:MF   both

# %%
great_res[1][['ontology', 'term_id', 'binom_raw_p_value', 'term name', '_merge']]
# Out:
#                  ontology     term_id  binom_raw_p_value  \
# 0   GO Biological Process  GO:0010558       1.969000e-11
# 1   GO Biological Process  GO:0031327       3.650388e-11
# 2   GO Biological Process  GO:2000113       5.260388e-11
# 3   GO Biological Process  GO:0009890       5.767215e-11
# 4   GO Biological Process  GO:1903507       7.676659e-11
# 5   GO Biological Process  GO:1902679       1.048514e-10
# 6   GO Biological Process  GO:0045892       2.447997e-10
# 7   GO Biological Process  GO:0051172       3.208091e-10
# 9   GO Biological Process  GO:0010629       4.168727e-10
# 10  GO Biological Process  GO:0051253       5.461104e-10
# 12  GO Biological Process  GO:0045934       1.529159e-09
# 13  GO Biological Process  GO:0007507       1.743796e-09
# 16  GO Biological Process  GO:0021915       1.439531e-08
# 18  GO Biological Process  GO:0000122       5.214027e-08
# 22  GO Molecular Function  GO:0000982       1.914722e-05
# 23  GO Molecular Function  GO:0001078       7.151106e-05
# 24  GO Molecular Function  GO:0030165       1.485068e-04
# 25  GO Molecular Function  GO:0001159       2.175891e-04
#
#                                                                                                         term name  \
# 0                                                       negative regulation of macromolecule biosynthetic process
# 1                                                            negative regulation of cellular biosynthetic process
# 2                                              negative regulation of cellular macromolecule biosynthetic process
# 3                                                                     negative regulation of biosynthetic process
# 4                                                     negative regulation of nucleic acid-templated transcription
# 5                                                                 negative regulation of RNA biosynthetic process
# 6                                                             negative regulation of transcription, DNA-templated
# 7                                                      negative regulation of nitrogen compound metabolic process
# 9                                                                          negative regulation of gene expression
# 10                                                                   negative regulation of RNA metabolic process
# 12                                        negative regulation of nucleobase-containing compound metabolic process
# 13                                                                                              heart development
# 16                                                                                        neural tube development
# 18                                           negative regulation of transcription from RNA polymerase II promoter
# 22       transcription factor activity, RNA polymerase II core promoter proximal region sequence-specific binding
# 23  transcriptional repressor activity, RNA polymerase II core promoter proximal region sequence-specific binding
# 24                                                                                             PDZ domain binding
# 25                                                                      core promoter proximal region DNA binding
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4   left_only
# 5   left_only
# 6   left_only
# 7   left_only
# 9   left_only
# 10  left_only
# 12  left_only
# 13  left_only
# 16  left_only
# 18  left_only
# 22  left_only
# 23  left_only
# 24  left_only
# 25  left_only

# %% [markdown]
# ### Top 50 terms

# %%
great_all = pd.read_csv("../BEHST/data/limb_GREAT_res_all", sep='\t', header=0)

# %%
great_all_top = great_all.sort_values('BinomP').head(50)
great_all_top = great_all_top[['ID']]
great_all_top.columns = ['term_id']

# %%
great_all_res = merge_df(great_all_top, limb_ref, ['term_id'], True)
# Out:
# The number of true positive terms is 33
# The number of false positive terms is 17

# %% [markdown]
# ## GREAT-gprofiler Hybrid test

# %%
great_gene_list = []
for i in range(len(great_all)):
    curr_list = great_all.iloc[i, 9]
    curr_list = curr_list.split(',')
    great_gene_list.extend(curr_list)

# %%
great_gene_set = set(great_gene_list)

# %%
great_gene_df = pd.DataFrame(great_gene_set)
# great_gene_df.to_csv('../BEHST/data/great_limb_gene_id', header=None, index=None)

# %%
great_gprofiler = pd.read_csv("../BEHST/results/06-25/limb_great_go_list", sep='\t', header=0)
great_gprofiler_sig = great_gprofiler[great_gprofiler.p_value <= 0.05]
len(great_gprofiler_sig)
# Out:
# 320

# %% [markdown]
# ### FDR

# %%
great_gprofiler_res = merge_df(great_gprofiler_sig, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 139
# The number of false positive terms is 181

# %%
great_gprofiler_res[0]
# Out:
#         p_value_x     term_id source  \
# 0    2.736283e-17  GO:0000981  GO:MF
# 1    1.811661e-15  GO:0003700  GO:MF
# 2    7.498709e-14  GO:0140110  GO:MF
# 3    8.925696e-14  GO:0006357  GO:BP
# 4    7.054216e-12  GO:0006366  GO:BP
# ..            ...         ...    ...
# 281  2.281995e-02  GO:0009893  GO:BP
# 294  2.790377e-02  GO:0048522  GO:BP
# 295  2.828129e-02  GO:0007517  GO:BP
# 296  2.890273e-02  GO:0002062  GO:BP
# 318  4.681536e-02  GO:0035115  GO:BP
#
#                                                                  term_name  \
# 0    DNA-binding transcription factor activity, RNA polymerase II-specific
# 1                                DNA-binding transcription factor activity
# 2                                         transcription regulator activity
# 3                         regulation of transcription by RNA polymerase II
# 4                                       transcription by RNA polymerase II
# ..                                                                     ...
# 281                               positive regulation of metabolic process
# 294                                positive regulation of cellular process
# 295                                               muscle organ development
# 296                                            chondrocyte differentiation
# 318                                       embryonic forelimb morphogenesis
#
#         p_value_y _merge
# 0    1.388936e-15   both
# 1    7.006285e-14   both
# 2    9.129339e-11   both
# 3    1.969506e-09   both
# 4    1.246135e-08   both
# ..            ...    ...
# 281  3.021835e-04   both
# 294  5.876816e-03   both
# 295  5.580137e-06   both
# 296  3.836478e-05   both
# 318  4.240993e-06   both
#
# [139 rows x 6 columns]

# %%
great_gprofiler_res[1]
# Out:
#         p_value_x     term_id source  \
# 10   2.667935e-09  GO:0021537  GO:BP
# 12   4.380492e-09  GO:0048699  GO:BP
# 18   8.161508e-09  GO:0007399  GO:BP
# 20   9.398389e-09  GO:0030900  GO:BP
# 22   1.212050e-08  GO:0007507  GO:BP
# ..            ...         ...    ...
# 314  4.505809e-02  GO:0035270  GO:BP
# 315  4.558823e-02  GO:0072087  GO:BP
# 316  4.681536e-02  GO:0061311  GO:BP
# 317  4.681536e-02  GO:0003338  GO:BP
# 319  4.831162e-02  GO:0044238  GO:BP
#
#                                                                  term_name  \
# 10                                               telencephalon development
# 12                                                   generation of neurons
# 18                                              nervous system development
# 20                                                   forebrain development
# 22                                                       heart development
# ..                                                                     ...
# 314                                           endocrine system development
# 315                                              renal vesicle development
# 316  cell surface receptor signaling pathway involved in heart development
# 317                                              metanephros morphogenesis
# 319                                              primary metabolic process
#
#      p_value_y     _merge
# 10         NaN  left_only
# 12         NaN  left_only
# 18         NaN  left_only
# 20         NaN  left_only
# 22         NaN  left_only
# ..         ...        ...
# 314        NaN  left_only
# 315        NaN  left_only
# 316        NaN  left_only
# 317        NaN  left_only
# 319        NaN  left_only
#
# [181 rows x 6 columns]

# %% [markdown]
# ### Top 50 terms

# %%
great_top_50 = great_gprofiler_sig.sort_values('p_value').head(50)

great_top_res = merge_df(great_top_50, limb_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 39
# The number of false positive terms is 11

# %% [markdown]
# ## ChIP-Enrich

# %%
limb_chip = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/07-02/vista_LIMB_sorted_chip_enrich_peaks.tab", sep='\t', header=0)

limb_chip.head()
# Out:
#   peak_id   chr  peak_start  peak_end    gene_id gene_symbol  \
# 0  peak:1  chr1     8130440   8131887      54206      ERRFI1
# 1  peak:2  chr1    44989825  44991149  100847089     MIR5584
# 2  peak:3  chr1    51165196  51166786      11124        FAF1
# 3  peak:4  chr1    54925047  54928826      23648       SSBP3
# 4  peak:5  chr1    56240105  56242435  100616272     MIR4422
#
#    gene_locus_start  gene_locus_end  nearest_tss  dist_to_tss  \
# 0           8048734         8235391      8086393       -44769
# 1          44950331        45054434     45011165       -20677
# 2          50983645        51429772     51078170       -87820
# 3          54768955        54939999     54872068       -54867
# 4          55686177        56368285     55691314       549955
#
#    nearest_tss_gene_id nearest_tss_symbol nearest_tss_gene_strand
# 0                54206             ERRFI1                       -
# 1            100847089            MIR5584                       +
# 2                11124               FAF1                       -
# 3                23648              SSBP3                       -
# 4            100616272            MIR4422                       +

# %%
# limb_chip[['gene_symbol']].to_csv('../BEHST/data/07_02_limb_chip_enrich_genes', header=None, index=None)

# %%
limb_chip_go = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/07-02/vista_LIMB_sorted_chip_enrich_results.tab", sep='\t', header=0)

# %%
limb_chip_go = limb_chip_go[['Geneset.Type', 'Geneset.ID', 'Description', 'P.value']]
limb_chip_go.columns = ['source', 'term_id', 'term_name', 'p_value']
limb_chip_go = limb_chip_go[limb_chip_go.p_value <= 0.05]
limb_chip_go
# Out:
#                                 source     term_id  \
# 0     Gene Ontology Biological Process  GO:0071470
# 1     Gene Ontology Biological Process  GO:0009952
# 2     Gene Ontology Biological Process  GO:0055075
# 3     Gene Ontology Biological Process  GO:0021532
# 4     Gene Ontology Biological Process  GO:0035295
# ...                                ...         ...
# 2652  Gene Ontology Molecular Function  GO:0005102
# 2653  Gene Ontology Molecular Function  GO:0035639
# 2654  Gene Ontology Molecular Function  GO:0030554
# 2655  Gene Ontology Molecular Function  GO:0032559
# 2656  Gene Ontology Biological Process  GO:0055114
#
#                                        term_name       p_value
# 0            cellular response to osmotic stress  2.282953e-07
# 1       anterior/posterior pattern specification  1.573778e-06
# 2                      potassium ion homeostasis  2.790453e-06
# 3                         neural tube patterning  3.951001e-06
# 4                               tube development  1.201910e-05
# ...                                          ...           ...
# 2652                            receptor binding  3.083794e-02
# 2653  purine ribonucleoside triphosphate binding  3.276439e-02
# 2654                   adenyl nucleotide binding  3.851528e-02
# 2655               adenyl ribonucleotide binding  3.915167e-02
# 2656                 oxidation-reduction process  4.664392e-02
#
# [508 rows x 4 columns]

# %%
chip_res = merge_df(limb_chip_go[['term_id', 'p_value']], limb_ref, ['term_id'], True)
# Out:
# The number of true positive terms is 67
# The number of false positive terms is 441

# %%
chip_res[1]
# Out:
#         term_id     p_value_x  p_value_y source term_name     _merge
# 0    GO:0071470  2.282953e-07        NaN    NaN       NaN  left_only
# 2    GO:0055075  2.790453e-06        NaN    NaN       NaN  left_only
# 3    GO:0021532  3.951001e-06        NaN    NaN       NaN  left_only
# 5    GO:0030315  1.350352e-05        NaN    NaN       NaN  left_only
# 6    GO:1902188  1.378139e-05        NaN    NaN       NaN  left_only
# ..          ...           ...        ...    ...       ...        ...
# 503  GO:0005102  3.083794e-02        NaN    NaN       NaN  left_only
# 504  GO:0035639  3.276439e-02        NaN    NaN       NaN  left_only
# 505  GO:0030554  3.851528e-02        NaN    NaN       NaN  left_only
# 506  GO:0032559  3.915167e-02        NaN    NaN       NaN  left_only
# 507  GO:0055114  4.664392e-02        NaN    NaN       NaN  left_only
#
# [441 rows x 6 columns]

# %%
limb_chip_top = limb_chip_go[['term_id', 'p_value']].head(50)
limb_chip_top_res = merge_df(limb_chip_top, limb_ref, ['term_id'], True)
limb_chip_top_res[0]
# Out:
# The number of true positive terms is 10
# The number of false positive terms is 40
#        term_id  p_value_x     p_value_y source  \
# 1   GO:0009952   0.000002  5.286603e-08  GO:BP
# 4   GO:0035295   0.000012  1.142134e-03  GO:BP
# 10  GO:0048568   0.000017  1.529934e-04  GO:BP
# 13  GO:0048562   0.000038  2.089487e-06  GO:BP
# 19  GO:0003002   0.000077  1.752402e-11  GO:BP
# 24  GO:0048598   0.000091  1.207525e-15  GO:BP
# 25  GO:0035136   0.000095  3.972126e-09  GO:BP
# 34  GO:0051254   0.000168  1.011132e-05  GO:BP
# 44  GO:0043565   0.000229  7.987161e-13  GO:MF
# 48  GO:0003700   0.000257  7.006285e-14  GO:MF
#
#                                        term_name _merge
# 1       anterior/posterior pattern specification   both
# 4                               tube development   both
# 10                   embryonic organ development   both
# 13                 embryonic organ morphogenesis   both
# 19                               regionalization   both
# 24                       embryonic morphogenesis   both
# 25                        forelimb morphogenesis   both
# 34  positive regulation of RNA metabolic process   both
# 44                 sequence-specific DNA binding   both
# 48     DNA-binding transcription factor activity   both

# %% [markdown]
# ## ChIP-Enrich-gprofiler Hybrid test

# %%
limb_chip_gprofiler = pd.read_csv("/mnt/work1/users/hoffmangroup/zhiyuanl/BEHST/results/07-02/limb_chip_go_list", sep='\t', header=0)

# %%
limb_chip_gprofiler_res = merge_df(limb_chip_gprofiler, limb_ref, ['term_id', 'source', 'term_name'], True)
limb_chip_gprofiler_res[0]
# Out:
# The number of true positive terms is 52
# The number of false positive terms is 28
#        p_value_x     term_id source  \
# 0   2.297519e-07  GO:0000981  GO:MF
# 1   1.688737e-06  GO:0003700  GO:MF
# 2   1.796098e-05  GO:0140110  GO:MF
# 3   2.513041e-05  GO:0006357  GO:BP
# 5   1.070172e-04  GO:0000977  GO:MF
# 7   1.252904e-04  GO:0001012  GO:MF
# 9   1.984396e-04  GO:0006366  GO:BP
# 10  3.240722e-04  GO:0000976  GO:MF
# 11  3.428032e-04  GO:0000790  GO:CC
# 12  4.104401e-04  GO:0043565  GO:MF
# 14  7.990134e-04  GO:0044212  GO:MF
# 15  8.009118e-04  GO:1990837  GO:MF
# 16  8.140266e-04  GO:0001067  GO:MF
# 17  1.064172e-03  GO:0003002  GO:BP
# 18  1.285162e-03  GO:0003690  GO:MF
# 19  1.651519e-03  GO:0035108  GO:BP
# 20  1.651519e-03  GO:0035107  GO:BP
# 22  2.550857e-03  GO:0003677  GO:MF
# 24  2.961168e-03  GO:0048598  GO:BP
# 26  3.658321e-03  GO:0009653  GO:BP
# 27  3.765540e-03  GO:0048568  GO:BP
# 28  3.980030e-03  GO:0000228  GO:CC
# 30  4.836199e-03  GO:0030154  GO:BP
# 31  5.534298e-03  GO:1903506  GO:BP
# 32  5.571420e-03  GO:0009887  GO:BP
# 33  5.716957e-03  GO:0000785  GO:CC
# 34  5.787972e-03  GO:2001141  GO:BP
# 37  6.746829e-03  GO:0006355  GO:BP
# 40  7.670858e-03  GO:0009952  GO:BP
# 41  8.074808e-03  GO:0005694  GO:CC
# 43  8.520990e-03  GO:0060173  GO:BP
# 44  8.520990e-03  GO:0048736  GO:BP
# 45  1.001261e-02  GO:0009790  GO:BP
# 46  1.066590e-02  GO:0048869  GO:BP
# 47  1.209876e-02  GO:0035295  GO:BP
# 48  1.548926e-02  GO:0010556  GO:BP
# 50  1.656510e-02  GO:0018130  GO:BP
# 53  1.791851e-02  GO:0019438  GO:BP
# 54  1.839128e-02  GO:0007389  GO:BP
# 55  1.917620e-02  GO:0001228  GO:MF
# 57  2.067629e-02  GO:0001216  GO:MF
# 58  2.120093e-02  GO:0097659  GO:BP
# 59  2.124972e-02  GO:0034654  GO:BP
# 61  2.198069e-02  GO:2000112  GO:BP
# 63  2.232673e-02  GO:0010468  GO:BP
# 65  2.378724e-02  GO:0032774  GO:BP
# 68  2.941272e-02  GO:0048562  GO:BP
# 70  3.168280e-02  GO:0006351  GO:BP
# 71  3.276039e-02  GO:0035113  GO:BP
# 72  3.276039e-02  GO:0030326  GO:BP
# 75  4.313987e-02  GO:0048731  GO:BP
# 79  4.839235e-02  GO:0031326  GO:BP
#
#                                                                    term_name  \
# 0      DNA-binding transcription factor activity, RNA polymerase II-specific
# 1                                  DNA-binding transcription factor activity
# 2                                           transcription regulator activity
# 3                           regulation of transcription by RNA polymerase II
# 5          RNA polymerase II regulatory region sequence-specific DNA binding
# 7                            RNA polymerase II regulatory region DNA binding
# 9                                         transcription by RNA polymerase II
# 10             transcription regulatory region sequence-specific DNA binding
# 11                                                         nuclear chromatin
# 12                                             sequence-specific DNA binding
# 14                               transcription regulatory region DNA binding
# 15                             sequence-specific double-stranded DNA binding
# 16                                    regulatory region nucleic acid binding
# 17                                                           regionalization
# 18                                               double-stranded DNA binding
# 19                                                        limb morphogenesis
# 20                                                   appendage morphogenesis
# 22                                                               DNA binding
# 24                                                   embryonic morphogenesis
# 26                                        anatomical structure morphogenesis
# 27                                               embryonic organ development
# 28                                                        nuclear chromosome
# 30                                                      cell differentiation
# 31                        regulation of nucleic acid-templated transcription
# 32                                                animal organ morphogenesis
# 33                                                                 chromatin
# 34                                    regulation of RNA biosynthetic process
# 37                                regulation of transcription, DNA-templated
# 40                                  anterior/posterior pattern specification
# 41                                                                chromosome
# 43                                                          limb development
# 44                                                     appendage development
# 45                                                        embryo development
# 46                                            cellular developmental process
# 47                                                          tube development
# 48                          regulation of macromolecule biosynthetic process
# 50                                          heterocycle biosynthetic process
# 53                                    aromatic compound biosynthetic process
# 54                                             pattern specification process
# 55  DNA-binding transcription activator activity, RNA polymerase II-specific
# 57                              DNA-binding transcription activator activity
# 58                                      nucleic acid-templated transcription
# 59                       nucleobase-containing compound biosynthetic process
# 61                 regulation of cellular macromolecule biosynthetic process
# 63                                             regulation of gene expression
# 65                                                  RNA biosynthetic process
# 68                                             embryonic organ morphogenesis
# 70                                              transcription, DNA-templated
# 71                                         embryonic appendage morphogenesis
# 72                                              embryonic limb morphogenesis
# 75                                                        system development
# 79                               regulation of cellular biosynthetic process
#
#        p_value_y _merge
# 0   1.388936e-15   both
# 1   7.006285e-14   both
# 2   9.129339e-11   both
# 3   1.969506e-09   both
# 5   1.614064e-10   both
# 7   1.905652e-10   both
# 9   1.246135e-08   both
# 10  5.224864e-10   both
# 11  1.702319e-14   both
# 12  7.987161e-13   both
# 14  5.240397e-09   both
# 15  1.382682e-09   both
# 16  5.342985e-09   both
# 17  1.752402e-11   both
# 18  8.612231e-09   both
# 19  5.502065e-23   both
# 20  5.502065e-23   both
# 22  1.765194e-07   both
# 24  1.207525e-15   both
# 26  2.937630e-13   both
# 27  1.529934e-04   both
# 28  2.181910e-12   both
# 30  1.419869e-05   both
# 31  2.503299e-05   both
# 32  6.804185e-12   both
# 33  8.290435e-13   both
# 34  2.597328e-05   both
# 37  1.471612e-05   both
# 40  5.286603e-08   both
# 41  2.919854e-09   both
# 43  1.520378e-26   both
# 44  1.520378e-26   both
# 45  3.135152e-12   both
# 46  5.194616e-05   both
# 47  1.142134e-03   both
# 48  3.567212e-04   both
# 50  2.435584e-03   both
# 53  7.251651e-04   both
# 54  1.859436e-13   both
# 55  1.304658e-08   both
# 57  1.437720e-08   both
# 58  7.659882e-05   both
# 59  1.662843e-03   both
# 61  1.365037e-04   both
# 63  4.416767e-05   both
# 65  8.441958e-05   both
# 68  2.089487e-06   both
# 70  5.545471e-05   both
# 71  1.153630e-22   both
# 72  1.153630e-22   both
# 75  1.221894e-10   both
# 79  2.349782e-04   both

# %%
limb_chip_gprofiler_res[1]
# Out:
#     p_value_x     term_id source  \
# 4    0.000069  GO:0042383  GO:CC
# 6    0.000115  GO:0007399  GO:BP
# 8    0.000176  GO:0090596  GO:BP
# 13   0.000463  GO:0048468  GO:BP
# 21   0.002096  GO:0007507  GO:BP
# 23   0.002650  GO:0030182  GO:BP
# 25   0.003272  GO:0048699  GO:BP
# 29   0.004779  GO:0022008  GO:BP
# 35   0.006113  GO:1903507  GO:BP
# 36   0.006298  GO:1902679  GO:BP
# 38   0.006914  GO:0010558  GO:BP
# 39   0.007378  GO:0030165  GO:MF
# 42   0.008323  GO:0045892  GO:BP
# 49   0.015716  GO:0031327  GO:BP
# 51   0.016578  GO:2000113  GO:BP
# 52   0.016836  GO:0007423  GO:BP
# 56   0.019388  GO:0050673  GO:BP
# 60   0.021401  GO:0030900  GO:BP
# 62   0.022158  GO:0009890  GO:BP
# 64   0.023507  GO:0051253  GO:BP
# 66   0.024290  GO:0030315  GO:CC
# 67   0.026181  GO:0072359  GO:BP
# 69   0.031572  GO:0045934  GO:BP
# 73   0.035402  GO:0019904  GO:MF
# 74   0.036675  GO:0003206  GO:BP
# 76   0.044258  GO:0060592  GO:BP
# 77   0.046433  GO:0005634  GO:CC
# 78   0.046589  GO:0000122  GO:BP
#
#                                                                   term_name  \
# 4                                                                sarcolemma
# 6                                                nervous system development
# 8                                               sensory organ morphogenesis
# 13                                                         cell development
# 21                                                        heart development
# 23                                                   neuron differentiation
# 25                                                    generation of neurons
# 29                                                             neurogenesis
# 35              negative regulation of nucleic acid-templated transcription
# 36                          negative regulation of RNA biosynthetic process
# 38                negative regulation of macromolecule biosynthetic process
# 39                                                       PDZ domain binding
# 42                      negative regulation of transcription, DNA-templated
# 49                     negative regulation of cellular biosynthetic process
# 51       negative regulation of cellular macromolecule biosynthetic process
# 52                                                sensory organ development
# 56                                            epithelial cell proliferation
# 60                                                    forebrain development
# 62                              negative regulation of biosynthetic process
# 64                             negative regulation of RNA metabolic process
# 66                                                                 T-tubule
# 67                                           circulatory system development
# 69  negative regulation of nucleobase-containing compound metabolic process
# 73                                          protein domain specific binding
# 74                                            cardiac chamber morphogenesis
# 76                                                  mammary gland formation
# 77                                                                  nucleus
# 78                negative regulation of transcription by RNA polymerase II
#
#     p_value_y     _merge
# 4         NaN  left_only
# 6         NaN  left_only
# 8         NaN  left_only
# 13        NaN  left_only
# 21        NaN  left_only
# 23        NaN  left_only
# 25        NaN  left_only
# 29        NaN  left_only
# 35        NaN  left_only
# 36        NaN  left_only
# 38        NaN  left_only
# 39        NaN  left_only
# 42        NaN  left_only
# 49        NaN  left_only
# 51        NaN  left_only
# 52        NaN  left_only
# 56        NaN  left_only
# 60        NaN  left_only
# 62        NaN  left_only
# 64        NaN  left_only
# 66        NaN  left_only
# 67        NaN  left_only
# 69        NaN  left_only
# 73        NaN  left_only
# 74        NaN  left_only
# 76        NaN  left_only
# 77        NaN  left_only
# 78        NaN  left_only

# %%
limb_chip_gp_top = limb_chip_gprofiler.head(50)
limb_chip_gp_res = merge_df(limb_chip_gp_top, limb_ref, ['term_id', 'term_name', 'source'], False)
limb_chip_gp_res[0]
# Out:
# The number of true positive terms is 36
# The number of false positive terms is 14
#        p_value_x     term_id source  \
# 0   2.297519e-07  GO:0000981  GO:MF
# 1   1.688737e-06  GO:0003700  GO:MF
# 2   1.796098e-05  GO:0140110  GO:MF
# 3   2.513041e-05  GO:0006357  GO:BP
# 5   1.070172e-04  GO:0000977  GO:MF
# 7   1.252904e-04  GO:0001012  GO:MF
# 9   1.984396e-04  GO:0006366  GO:BP
# 10  3.240722e-04  GO:0000976  GO:MF
# 11  3.428032e-04  GO:0000790  GO:CC
# 12  4.104401e-04  GO:0043565  GO:MF
# 14  7.990134e-04  GO:0044212  GO:MF
# 15  8.009118e-04  GO:1990837  GO:MF
# 16  8.140266e-04  GO:0001067  GO:MF
# 17  1.064172e-03  GO:0003002  GO:BP
# 18  1.285162e-03  GO:0003690  GO:MF
# 19  1.651519e-03  GO:0035108  GO:BP
# 20  1.651519e-03  GO:0035107  GO:BP
# 22  2.550857e-03  GO:0003677  GO:MF
# 24  2.961168e-03  GO:0048598  GO:BP
# 26  3.658321e-03  GO:0009653  GO:BP
# 27  3.765540e-03  GO:0048568  GO:BP
# 28  3.980030e-03  GO:0000228  GO:CC
# 30  4.836199e-03  GO:0030154  GO:BP
# 31  5.534298e-03  GO:1903506  GO:BP
# 32  5.571420e-03  GO:0009887  GO:BP
# 33  5.716957e-03  GO:0000785  GO:CC
# 34  5.787972e-03  GO:2001141  GO:BP
# 37  6.746829e-03  GO:0006355  GO:BP
# 40  7.670858e-03  GO:0009952  GO:BP
# 41  8.074808e-03  GO:0005694  GO:CC
# 43  8.520990e-03  GO:0060173  GO:BP
# 44  8.520990e-03  GO:0048736  GO:BP
# 45  1.001261e-02  GO:0009790  GO:BP
# 46  1.066590e-02  GO:0048869  GO:BP
# 47  1.209876e-02  GO:0035295  GO:BP
# 48  1.548926e-02  GO:0010556  GO:BP
#
#                                                                 term_name  \
# 0   DNA-binding transcription factor activity, RNA polymerase II-specific
# 1                               DNA-binding transcription factor activity
# 2                                        transcription regulator activity
# 3                        regulation of transcription by RNA polymerase II
# 5       RNA polymerase II regulatory region sequence-specific DNA binding
# 7                         RNA polymerase II regulatory region DNA binding
# 9                                      transcription by RNA polymerase II
# 10          transcription regulatory region sequence-specific DNA binding
# 11                                                      nuclear chromatin
# 12                                          sequence-specific DNA binding
# 14                            transcription regulatory region DNA binding
# 15                          sequence-specific double-stranded DNA binding
# 16                                 regulatory region nucleic acid binding
# 17                                                        regionalization
# 18                                            double-stranded DNA binding
# 19                                                     limb morphogenesis
# 20                                                appendage morphogenesis
# 22                                                            DNA binding
# 24                                                embryonic morphogenesis
# 26                                     anatomical structure morphogenesis
# 27                                            embryonic organ development
# 28                                                     nuclear chromosome
# 30                                                   cell differentiation
# 31                     regulation of nucleic acid-templated transcription
# 32                                             animal organ morphogenesis
# 33                                                              chromatin
# 34                                 regulation of RNA biosynthetic process
# 37                             regulation of transcription, DNA-templated
# 40                               anterior/posterior pattern specification
# 41                                                             chromosome
# 43                                                       limb development
# 44                                                  appendage development
# 45                                                     embryo development
# 46                                         cellular developmental process
# 47                                                       tube development
# 48                       regulation of macromolecule biosynthetic process
#
#        p_value_y _merge
# 0   1.388936e-15   both
# 1   7.006285e-14   both
# 2   9.129339e-11   both
# 3   1.969506e-09   both
# 5   1.614064e-10   both
# 7   1.905652e-10   both
# 9   1.246135e-08   both
# 10  5.224864e-10   both
# 11  1.702319e-14   both
# 12  7.987161e-13   both
# 14  5.240397e-09   both
# 15  1.382682e-09   both
# 16  5.342985e-09   both
# 17  1.752402e-11   both
# 18  8.612231e-09   both
# 19  5.502065e-23   both
# 20  5.502065e-23   both
# 22  1.765194e-07   both
# 24  1.207525e-15   both
# 26  2.937630e-13   both
# 27  1.529934e-04   both
# 28  2.181910e-12   both
# 30  1.419869e-05   both
# 31  2.503299e-05   both
# 32  6.804185e-12   both
# 33  8.290435e-13   both
# 34  2.597328e-05   both
# 37  1.471612e-05   both
# 40  5.286603e-08   both
# 41  2.919854e-09   both
# 43  1.520378e-26   both
# 44  1.520378e-26   both
# 45  3.135152e-12   both
# 46  5.194616e-05   both
# 47  1.142134e-03   both
# 48  3.567212e-04   both

# %%
limb_chip_gp_res[1]
# Out:
#     p_value_x     term_id source  \
# 4    0.000069  GO:0042383  GO:CC
# 6    0.000115  GO:0007399  GO:BP
# 8    0.000176  GO:0090596  GO:BP
# 13   0.000463  GO:0048468  GO:BP
# 21   0.002096  GO:0007507  GO:BP
# 23   0.002650  GO:0030182  GO:BP
# 25   0.003272  GO:0048699  GO:BP
# 29   0.004779  GO:0022008  GO:BP
# 35   0.006113  GO:1903507  GO:BP
# 36   0.006298  GO:1902679  GO:BP
# 38   0.006914  GO:0010558  GO:BP
# 39   0.007378  GO:0030165  GO:MF
# 42   0.008323  GO:0045892  GO:BP
# 49   0.015716  GO:0031327  GO:BP
#
#                                                       term_name  p_value_y  \
# 4                                                    sarcolemma        NaN
# 6                                    nervous system development        NaN
# 8                                   sensory organ morphogenesis        NaN
# 13                                             cell development        NaN
# 21                                            heart development        NaN
# 23                                       neuron differentiation        NaN
# 25                                        generation of neurons        NaN
# 29                                                 neurogenesis        NaN
# 35  negative regulation of nucleic acid-templated transcription        NaN
# 36              negative regulation of RNA biosynthetic process        NaN
# 38    negative regulation of macromolecule biosynthetic process        NaN
# 39                                           PDZ domain binding        NaN
# 42          negative regulation of transcription, DNA-templated        NaN
# 49         negative regulation of cellular biosynthetic process        NaN
#
#        _merge
# 4   left_only
# 6   left_only
# 8   left_only
# 13  left_only
# 21  left_only
# 23  left_only
# 25  left_only
# 29  left_only
# 35  left_only
# 36  left_only
# 38  left_only
# 39  left_only
# 42  left_only
# 49  left_only

# %% [markdown]
# ## Result
# ### False Discovery Rate
# experiment | significant GO terms | True Positive | False Positive | FDR
# --- | --- | --- | --- | ---
# BEHST | 60 | 58 | 2 | 0.033
# GREAT | 26 | 8 | 18 | 0.692
# GREAT-gprofiler | 320 | 139 | 181 | 0.566
# ChIP-Enrich | 508 | 67 | 441 | 0.868
# ChIP-Enrich-gprofiler | 80 | 52 | 28 | 0.350
#
# ### Top 50 terms
# experiment | Intersection with reference | Intersection Rate
# --- | --- | ---
# BEHST | 49 | 0.98
# GREAT | 33 | 0.66
# GREAT-gprofiler | 39 | 0.78
# ChIP-Enrich | 10 | 0.20
# ChIP-Enrich-gprofiler | 36 | 0.72

# %% [markdown]
# ## DNase Hypersensitive Sites

# %%
# load DNase hypersensitive sites data
GM12878_1 = pd.read_csv("../BEHST/data/GM12878_gene_quantification_1.tsv", sep='\t', header=0)
GM12878_2 = pd.read_csv("../BEHST/data/GM12878_gene_quantification_2.tsv", sep='\t',header=0)
H1_1 = pd.read_csv("../BEHST/data/H1_gene_quantification_1.tsv", sep='\t', header=0)
H1_2 = pd.read_csv("../BEHST/data/H1_gene_quantification_2.tsv", sep='\t', header=0)
HelaS3_1 = pd.read_csv("../BEHST/data/HelaS3_gene_quantification_1.tsv", sep='\t', header=0)
HelaS3_2 = pd.read_csv("../BEHST/data/HelaS3_gene_quantification_2.tsv", sep='\t', header=0)
HepG2_1 = pd.read_csv("../BEHST/data/HepG2_gene_quantification_1.tsv", sep='\t', header=0)
HepG2_2 = pd.read_csv("../BEHST/data/HepG2_gene_quantification_2.tsv", sep='\t', header=0)
huvec_1 = pd.read_csv("../BEHST/data/huvec_gene_quantification_1.tsv", sep='\t', header=0)
huvec_2 = pd.read_csv("../BEHST/data/huvec_gene_quantification_2.tsv", sep='\t', header=0)
K562_1 = pd.read_csv("../BEHST/data/K562_gene_quantification_1.tsv", sep='\t', header=0)
K562_2 = pd.read_csv("../BEHST/data/K562_gene_quantification_2.tsv", sep='\t', header=0)

# %%
# select most highly expressed genes in GM12878
gm12878_df = select_genes([GM12878_1, GM12878_2], 
                       [H1_1, H1_2, HelaS3_1, HelaS3_2, HepG2_1, HepG2_2, 
                       huvec_1, huvec_2, K562_1, K562_2])

len(gm12878_df)

# gm12878_df[['gene_id']].to_csv('../BEHST/data/reference_gm12878_gene_id', header=None, index=None)
# Out:
# 1659

# %%
gm12878_ref = pd.read_csv("../BEHST/results/07-08/gm12878_go_list", sep="\t", header=0)

gm12878_ref = gm12878_ref[gm12878_ref.p_value <= 0.05]
gm12878_ref
# Out:
#           p_value     term_id source  \
# 0    3.155919e-88  GO:0006955  GO:BP
# 1    3.627306e-88  GO:0002376  GO:BP
# 2    1.188706e-61  GO:0002682  GO:BP
# 3    2.447031e-57  GO:0046649  GO:BP
# 4    1.082126e-55  GO:0002684  GO:BP
# ..            ...         ...    ...
# 508  4.341709e-02  GO:0061756  GO:BP
# 509  4.577894e-02  GO:0050710  GO:BP
# 510  4.653474e-02  GO:0003924  GO:MF
# 511  4.688218e-02  GO:0046425  GO:BP
# 512  4.912608e-02  GO:0007254  GO:BP
#
#                                                  term_name
# 0                                          immune response
# 1                                    immune system process
# 2                      regulation of immune system process
# 3                                    lymphocyte activation
# 4             positive regulation of immune system process
# ..                                                     ...
# 508        leukocyte adhesion to vascular endothelial cell
# 509              negative regulation of cytokine secretion
# 510                                        GTPase activity
# 511  regulation of receptor signaling pathway via JAK-STAT
# 512                                            JNK cascade
#
# [513 rows x 4 columns]

# %%
gm12878_1 = pd.read_csv("../BEHST/results/07-08/GM12878_dnase_seq_hg19_1_bed_bed_QUERY28000_TARGET18100_8_types_go_list.txt", 
                   sep='\t', header=0)

gm12878_1_res = merge_df(gm12878_1, gm12878_ref, ['term_id', 'source', 'term_name'], True)

gm12878_2 = pd.read_csv("../BEHST/results/07-08/GM12878_dnase_seq_hg19_2_bed_bed_QUERY28000_TARGET18100_8_types_go_list.txt", 
                   sep='\t', header=0)

gm12878_2_res = merge_df(gm12878_2, gm12878_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 84
# The number of false positive terms is 363
# The number of true positive terms is 90
# The number of false positive terms is 376

# %%
gm12878_1_hic1 = pd.read_csv("../BEHST/results/07-08/GM12878_dnase_seq_hg19_1_bed_QUERY28000_TARGET18100_go_list.txt", 
                   sep='\t', header=0)

gm12878_1_hic1_res = merge_df(gm12878_1_hic1, gm12878_ref, ['term_id', 'source', 'term_name'], True)


gm12878_2_hic1 = pd.read_csv("../BEHST/results/07-08/GM12878_dnase_seq_hg19_2_bed_QUERY28000_TARGET18100_go_list.txt", 
                   sep='\t', header=0)

gm12878_2_hic1_res = merge_df(gm12878_2_hic1, gm12878_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 62
# The number of false positive terms is 170
# The number of true positive terms is 61
# The number of false positive terms is 165

# %%
# read BEHST limb output GO terms
gm12878_sub_1 = pd.read_csv("../BEHST/results/07-08/GM12878_subtracted_1_bed_QUERY28000_TARGET18100_8_types_go_list.txt", 
                   sep='\t', header=0)

gm12878_sub_1_res = merge_df(gm12878_sub_1, gm12878_ref, ['term_id', 'source', 'term_name'], True)


# read BEHST limb output GO terms
gm12878_sub_2 = pd.read_csv("../BEHST/results/07-08/GM12878_subtracted_2_bed_QUERY28000_TARGET18100_8_types_go_list.txt", 
                   sep='\t', header=0)

gm12878_sub_2_res = merge_df(gm12878_sub_2, gm12878_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 110
# The number of false positive terms is 156
# The number of true positive terms is 143
# The number of false positive terms is 180

# %%
gm12878_sub_1_hic1 = pd.read_csv("../BEHST/results/07-08/GM12878_subtracted_1_bed_QUERY28000_TARGET18100_go_list.txt", 
                   sep='\t', header=0)

gm12878_sub_1_hic1_res = merge_df(gm12878_sub_1_hic1, gm12878_ref, ['term_id', 'source', 'term_name'], True)


gm12878_sub_2_hic1 = pd.read_csv("../BEHST/results/07-08/GM12878_subtracted_2_bed_QUERY28000_TARGET18100_go_list.txt", 
                   sep='\t', header=0)

gm12878_sub_2_hic1_res = merge_df(gm12878_sub_2_hic1, gm12878_ref, ['term_id', 'source', 'term_name'], True)
# Out:
# The number of true positive terms is 54
# The number of false positive terms is 82
# The number of true positive terms is 90
# The number of false positive terms is 78
